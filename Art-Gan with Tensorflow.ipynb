# %% [markdown]
# # Art generating GAN
#
# A Generative Adversarial Network for generating new art

# %% [markdown]
# Code for training based on DCGAN tutorial at “Deep Convolutional Generative Adversarial Network | TensorFlow Core.” TensorFlow, https://www.tensorflow.org/tutorials/generative/dcgan
#
# And "Unsupervised representation learning
# with deep convolutional
# generative adversarial networks", Radford. A, Metz. L, Facebook AI Research, 2016 (https://arxiv.org/abs/1511.06434)

# %% [markdown]
# # Import required libraries

# %%
#   Implemented by
  
#   Pranav R Nambiar (BL.EN.U4CSE18093)

#   Sourabh Sooraj (BL.EN.U4CSE18118)

#   Sreedathan G (BL.EN.U4CSE18119)

#   S.A.S Sridatta (BL.EN.U4CSE18121)

# %%
import os

# Keras functions
import tensorflow as tf

from keras.optimizers import Adam
from keras.models import Sequential, Model, load_model
from keras.layers import Dense, Conv2D, Conv2DTranspose, Reshape, Flatten
from keras.layers import Dropout, LeakyReLU, BatchNormalization
from keras.layers import Activation, ZeroPadding2D, UpSampling2D
from keras.layers import Input, Reshape
from matplotlib import pyplot
from IPython.display import clear_output

# Numpy functions
import numpy
import numpy as np
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy import vstack
from numpy.random import randn
from numpy.random import randint
from numpy import zeros
from numpy import ones
from numpy import asarray

#Torchvision for fast and easy loading and resizing
import torchvision
import torchvision.transforms as transforms

from PIL import Image

# %% [markdown]
# # Load and pre-process the data

# %%
dataset_path = "/kaggle/input/best-artworks-of-all-time/resized/"
saved_path = '/kaggle/working/training_data.npy'

WIDTH = 64
HEIGHT = 64
IMG_SIZE = (WIDTH,HEIGHT)
EPOCHS = 250

#Look for saved file to save time loading and processing images between runs
print("Looking for previously saved file...")

if not os.path.isfile(saved_path):
    print("\n File not found, loading new data...\n")
    dataset = []
    transform_ds = transforms.Compose([transforms.Resize(IMG_SIZE),]) #define transformation
    
    image_folder = torchvision.datasets.ImageFolder(root=dataset_path,
                                     transform=transform_ds)

    print('Number of artworks found: ',len(image_folder))
    
    
    print("Converting images, this will take a few minutes")
    for i in range (len(image_folder)):
        image_array = numpy.array(image_folder[i][0])
        dataset.append(image_array)
        if (i%500 == 0):
            print("Pictures processed: ", i)
            
    print("Saving dataset binary file...")
    dataset = np.array(dataset, dtype=np.float32)
    dataset = (dataset - 127.5) / 127.5 #Normalize to [-1 , 1]
    numpy.save(saved_path, dataset)  #Save processed images as npy file

else:
    print("Data found, loading..")
    dataset = np.load(saved_path) 

print("Dataset length: ", len(dataset))
# Out:
# Looking for previously saved file...
#
#  File not found, loading new data...
#
# Number of artworks found:  8683
# Converting images, this will take a few minutes
# Pictures processed:  0
# Pictures processed:  500
# Pictures processed:  1000
# Pictures processed:  1500
# Pictures processed:  2000
# Pictures processed:  2500
# Pictures processed:  3000
# Pictures processed:  3500
# Pictures processed:  4000
# Pictures processed:  4500
# Pictures processed:  5000
# Pictures processed:  5500
# Pictures processed:  6000
# Pictures processed:  6500
# Pictures processed:  7000
# Pictures processed:  7500
# Pictures processed:  8000
# Pictures processed:  8500
# Saving dataset binary file...
# Dataset length:  8683

# %% [markdown]
# Confirm that the images are the correct shape.

# %%
dataset[3].shape
# Out:
# (64, 64, 3)

# %%
#Use a TensorFlow Dataset to manage the images for easy shuffling, dividing etc
BATCH_SIZE = 32

training_dataset = tf.data.Dataset.from_tensor_slices(dataset).shuffle(9000).batch(BATCH_SIZE)

# %% [markdown]
# # Explore the data

# %% [markdown]
# Here, we'll check out the dataset and what it looks like

# %%
import pandas as pd

artists = pd.read_csv('/kaggle/input/best-artworks-of-all-time/artists.csv')
artists
# Out:
#     id                       name        years  \
# 0    0          Amedeo Modigliani  1884 - 1920
# 1    1         Vasiliy Kandinskiy  1866 - 1944
# 2    2               Diego Rivera  1886 - 1957
# 3    3               Claude Monet  1840 - 1926
# 4    4              Rene Magritte  1898 - 1967
# 5    5              Salvador Dali  1904 - 1989
# 6    6              Edouard Manet  1832 - 1883
# 7    7              Andrei Rublev  1360 - 1430
# 8    8           Vincent van Gogh  1853 – 1890
# 9    9               Gustav Klimt  1862 - 1918
# 10  10           Hieronymus Bosch  1450 - 1516
# 11  11           Kazimir Malevich  1879 - 1935
# 12  12             Mikhail Vrubel  1856 - 1910
# 13  13              Pablo Picasso  1881 - 1973
# 14  14          Peter Paul Rubens  1577 - 1640
# 15  15      Pierre-Auguste Renoir  1841 - 1919
# 16  16             Francisco Goya  1746 - 1828
# 17  17                Frida Kahlo  1907 - 1954
# 18  18                   El Greco  1541 - 1614
# 19  19             Albrecht Dürer  1471 - 1528
# 20  20              Alfred Sisley  1839 - 1899
# 21  21             Pieter Bruegel  1525 - 1569
# 22  22               Marc Chagall  1887 - 1985
# 23  23          Giotto di Bondone  1266 - 1337
# 24  24          Sandro Botticelli  1445 - 1510
# 25  25                 Caravaggio  1571 - 1610
# 26  26          Leonardo da Vinci  1452 - 1519
# 27  27            Diego Velazquez  1599 - 1660
# 28  28              Henri Matisse  1869 - 1954
# 29  29               Jan van Eyck  1395 - 1441
# 30  30                Edgar Degas  1834 - 1917
# 31  31                  Rembrandt  1606 - 1669
# 32  32                     Titian  1488 - 1576
# 33  33  Henri de Toulouse-Lautrec  1864 – 1901
# 34  34            Gustave Courbet  1819 - 1877
# 35  35           Camille Pissarro  1830 - 1903
# 36  36             William Turner  1775 - 1851
# 37  37               Edvard Munch  1863 - 1944
# 38  38               Paul Cezanne  1839 – 1906
# 39  39           Eugene Delacroix  1798 – 1863
# 40  40             Henri Rousseau  1844 – 1910
# 41  41             Georges Seurat  1859 – 1891
# 42  42                  Paul Klee  1879 – 1940
# 43  43              Piet Mondrian  1872 – 1944
# 44  44                  Joan Miro  1893 – 1983
# 45  45                Andy Warhol  1928 – 1987
# 46  46               Paul Gauguin  1848 – 1903
# 47  47                    Raphael  1483 – 1520
# 48  48               Michelangelo  1475 – 1564
# 49  49            Jackson Pollock  1912 – 1956
#
#                                       genre               nationality  \
# 0                             Expressionism                   Italian
# 1              Expressionism,Abstractionism                   Russian
# 2                   Social Realism,Muralism                   Mexican
# 3                             Impressionism                    French
# 4                  Surrealism,Impressionism                   Belgian
# 5                                Surrealism                   Spanish
# 6                     Realism,Impressionism                    French
# 7                             Byzantine Art                   Russian
# 8                        Post-Impressionism                     Dutch
# 9                     Symbolism,Art Nouveau                  Austrian
# 10                     Northern Renaissance                     Dutch
# 11                              Suprematism                   Russian
# 12                                Symbolism                   Russian
# 13                                   Cubism                   Spanish
# 14                                  Baroque                   Flemish
# 15                            Impressionism                    French
# 16                              Romanticism                   Spanish
# 17                   Primitivism,Surrealism                   Mexican
# 18                                Mannerism             Spanish,Greek
# 19                     Northern Renaissance                    German
# 20                            Impressionism            French,British
# 21                     Northern Renaissance                   Flemish
# 22                              Primitivism  French,Jewish,Belarusian
# 23                        Proto Renaissance                   Italian
# 24                        Early Renaissance                   Italian
# 25                                  Baroque                   Italian
# 26                         High Renaissance                   Italian
# 27                                  Baroque                   Spanish
# 28         Impressionism,Post-Impressionism                    French
# 29                     Northern Renaissance                   Flemish
# 30                            Impressionism                    French
# 31                                  Baroque                     Dutch
# 32               High Renaissance,Mannerism                   Italian
# 33                       Post-Impressionism                    French
# 34                                  Realism                    French
# 35         Impressionism,Post-Impressionism                    French
# 36                              Romanticism                   British
# 37                  Symbolism,Expressionism                 Norwegian
# 38                       Post-Impressionism                    French
# 39                              Romanticism                    French
# 40                              Primitivism                    French
# 41                       Post-Impressionism                    French
# 42  Expressionism,Abstractionism,Surrealism              German,Swiss
# 43                            Neoplasticism                     Dutch
# 44                               Surrealism                   Spanish
# 45                                  Pop Art                  American
# 46             Symbolism,Post-Impressionism                    French
# 47                         High Renaissance                   Italian
# 48                         High Renaissance                   Italian
# 49                   Abstract Expressionism                  American
#
#                                                   bio  \
# 0   Amedeo Clemente Modigliani (Italian pronunciat...
# 1   Wassily Wassilyevich Kandinsky (Russian: Васи́...
# 2   Diego María de la Concepción Juan Nepomuceno E...
# 3   Oscar-Claude Monet (; French: [klod mɔnɛ]; 14 ...
# 4   René François Ghislain Magritte (French: [ʁəne...
# 5   Salvador Domingo Felipe Jacinto Dalí i Domènec...
# 6   Édouard Manet (US: ; UK: ; French: [edwaʁ manɛ...
# 7   Andrei Rublev (Russian: Андре́й Рублёв, IPA: [...
# 8   Vincent Willem van Gogh (Dutch: [ˈvɪnsɛnt ˈʋɪl...
# 9   Gustav Klimt (July 14, 1862 – February 6, 1918...
# 10  Hieronymus Bosch ( (listen); Dutch: [ɦijeːˈroː...
# 11  Kazimir Severinovich Malevich (February 23 [O....
# 12  Mikhail Aleksandrovich Vrubel (Russian: Михаи́...
# 13  Pablo Ruiz Picasso (; Spanish: [ˈpaβlo piˈkaso...
# 14  Sir Peter Paul Rubens (; Dutch: [ˈrybə(n)s]; 2...
# 15  Pierre-Auguste Renoir, commonly known as Augus...
# 16  Francisco José de Goya y Lucientes (; Spanish:...
# 17  Frida Kahlo de Rivera (Spanish pronunciation: ...
# 18  Doménikos Theotokópoulos (Greek: Δομήνικος Θεο...
# 19  Albrecht Dürer (; German: [ˈʔalbʁɛçt ˈdyːʁɐ]; ...
# 20  Alfred Sisley (; French: [sislɛ]; 30 October 1...
# 21  Pieter Bruegel (also Brueghel) the Elder (Dutc...
# 22  Marc Zakharovich Chagall ( shə-GAHL; born Mois...
# 23  Giotto di Bondone (Italian pronunciation: [ˈdʒ...
# 24  Alessandro (c. 1445 – May 17, 1510), known as ...
# 25  Michelangelo Merisi (Michele Angelo Merigi or ...
# 26  Leonardo di ser Piero da Vinci (Italian: [leoˈ...
# 27  Diego Rodríguez de Silva y Velázquez (Spanish:...
# 28  Henri Émile Benoît Matisse (French: [ɑ̃ʁi emil...
# 29  Jan van Eyck (Dutch: [ˈjɑn vɑn ˈɛik]) (before ...
# 30  Edgar Degas (US:  or UK: ; born Hilaire-Germai...
# 31  Rembrandt Harmenszoon van Rijn (; Dutch: [ˈrɛm...
# 32  Tiziano Vecelli or Tiziano Vecellio (pronounce...
# 33  Henri Marie Raymond de Toulouse-Lautrec-Monfa ...
# 34  Jean Désiré Gustave Courbet (French: [ɡystav k...
# 35  Camille Pissarro (French: [kamij pisaʁo]; 10 J...
# 36  Joseph Mallord William Turner  (23 April 1775 ...
# 37  Edvard Munch (; Norwegian: [ˈɛdvɑʈ ˈmʊŋk] (lis...
# 38  Paul Cézanne (US:  or UK: ; French: [pɔl sezan...
# 39  Ferdinand Victor Eugène Delacroix (; French: [...
# 40  Henri Julien Félix Rousseau (French: [ɑ̃ʁi ʒyl...
# 41  Georges-Pierre Seurat (French: [ʒɔʁʒ pjɛʁ sœʁa...
# 42  Paul Klee (German: [paʊ̯l ˈkleː]; 18 December ...
# 43  Pieter Cornelis Mondriaan, after 1906 Piet Mon...
# 44  Joan Miró i Ferrà (; Catalan: [ʒuˈam miˈɾo j f...
# 45  Andy Warhol (; born Andrew Warhola; August 6, ...
# 46  Eugène Henri Paul Gauguin (UK: , US: ; French:...
# 47  Raffaello Sanzio da Urbino (Italian: [raffaˈɛl...
# 48  Michelangelo di Lodovico Buonarroti Simoni or ...
# 49  Paul Jackson Pollock (; January 28, 1912 – Aug...
#
#                                             wikipedia  paintings
# 0      http://en.wikipedia.org/wiki/Amedeo_Modigliani        193
# 1      http://en.wikipedia.org/wiki/Wassily_Kandinsky         88
# 2           http://en.wikipedia.org/wiki/Diego_Rivera         70
# 3           http://en.wikipedia.org/wiki/Claude_Monet         73
# 4          http://en.wikipedia.org/wiki/René_Magritte        194
# 5          http://en.wikipedia.org/wiki/Salvador_Dalí        139
# 6          http://en.wikipedia.org/wiki/Édouard_Manet         90
# 7          http://en.wikipedia.org/wiki/Andrei_Rublev         99
# 8       http://en.wikipedia.org/wiki/Vincent_van_Gogh        877
# 9           http://en.wikipedia.org/wiki/Gustav_Klimt        117
# 10      http://en.wikipedia.org/wiki/Hieronymus_Bosch        137
# 11      http://en.wikipedia.org/wiki/Kazimir_Malevich        126
# 12        http://en.wikipedia.org/wiki/Mikhail_Vrubel        171
# 13         http://en.wikipedia.org/wiki/Pablo_Picasso        439
# 14     http://en.wikipedia.org/wiki/Peter_Paul_Rubens        141
# 15  http://en.wikipedia.org/wiki/Pierre-Auguste_Re...        336
# 16        http://en.wikipedia.org/wiki/Francisco_Goya        291
# 17           http://en.wikipedia.org/wiki/Frida_Kahlo        120
# 18              http://en.wikipedia.org/wiki/El_Greco         87
# 19        http://en.wikipedia.org/wiki/Albrecht_Dürer        328
# 20         http://en.wikipedia.org/wiki/Alfred_Sisley        259
# 21  http://en.wikipedia.org/wiki/Pieter_Bruegel_th...        134
# 22          http://en.wikipedia.org/wiki/Marc_Chagall        239
# 23     http://en.wikipedia.org/wiki/Giotto_di_Bondone        119
# 24     http://en.wikipedia.org/wiki/Sandro_Botticelli        164
# 25            http://en.wikipedia.org/wiki/Caravaggio         55
# 26     http://en.wikipedia.org/wiki/Leonardo_da_Vinci        143
# 27       http://en.wikipedia.org/wiki/Diego_Velázquez        128
# 28         http://en.wikipedia.org/wiki/Henri_Matisse        186
# 29          http://en.wikipedia.org/wiki/Jan_van_Eyck         81
# 30           http://en.wikipedia.org/wiki/Edgar_Degas        702
# 31             http://en.wikipedia.org/wiki/Rembrandt        262
# 32                http://en.wikipedia.org/wiki/Titian        255
# 33  https://en.wikipedia.org/wiki/Henri_de_Toulous...         81
# 34      https://en.wikipedia.org/wiki/Gustave_Courbet         59
# 35     https://en.wikipedia.org/wiki/Camille_Pissarro         91
# 36      https://en.wikipedia.org/wiki/J._M._W._Turner         66
# 37         https://en.wikipedia.org/wiki/Edvard_Munch         67
# 38         https://en.wikipedia.org/wiki/Paul_Cézanne         47
# 39     https://en.wikipedia.org/wiki/Eugène_Delacroix         31
# 40       https://en.wikipedia.org/wiki/Henri_Rousseau         70
# 41       https://en.wikipedia.org/wiki/Georges_Seurat         43
# 42            https://en.wikipedia.org/wiki/Paul_Klee        188
# 43        https://en.wikipedia.org/wiki/Piet_Mondrian         84
# 44            https://en.wikipedia.org/wiki/Joan_Miró        102
# 45          https://en.wikipedia.org/wiki/Andy_Warhol        181
# 46          http://en.wikipedia.org/wiki/Paul_Gauguin        311
# 47              https://en.wikipedia.org/wiki/Raphael        109
# 48         https://en.wikipedia.org/wiki/Michelangelo         49
# 49       http://en.wikipedia.org/wiki/Jackson_Pollock         24

# %% [markdown]
# There's some data that we dont really need for this task, like their nationality, wikipedia page and bio. Below, we filter the data to more clearly see the artists along with their corresponding genre and number of paintings in a more compact manner. As you can see, we have quite the mix of genres which will hopefully give our model a good base to generate from.

# %%
artists[['name','genre','paintings']]
# Out:
#                          name                                    genre  \
# 0           Amedeo Modigliani                            Expressionism
# 1          Vasiliy Kandinskiy             Expressionism,Abstractionism
# 2                Diego Rivera                  Social Realism,Muralism
# 3                Claude Monet                            Impressionism
# 4               Rene Magritte                 Surrealism,Impressionism
# 5               Salvador Dali                               Surrealism
# 6               Edouard Manet                    Realism,Impressionism
# 7               Andrei Rublev                            Byzantine Art
# 8            Vincent van Gogh                       Post-Impressionism
# 9                Gustav Klimt                    Symbolism,Art Nouveau
# 10           Hieronymus Bosch                     Northern Renaissance
# 11           Kazimir Malevich                              Suprematism
# 12             Mikhail Vrubel                                Symbolism
# 13              Pablo Picasso                                   Cubism
# 14          Peter Paul Rubens                                  Baroque
# 15      Pierre-Auguste Renoir                            Impressionism
# 16             Francisco Goya                              Romanticism
# 17                Frida Kahlo                   Primitivism,Surrealism
# 18                   El Greco                                Mannerism
# 19             Albrecht Dürer                     Northern Renaissance
# 20              Alfred Sisley                            Impressionism
# 21             Pieter Bruegel                     Northern Renaissance
# 22               Marc Chagall                              Primitivism
# 23          Giotto di Bondone                        Proto Renaissance
# 24          Sandro Botticelli                        Early Renaissance
# 25                 Caravaggio                                  Baroque
# 26          Leonardo da Vinci                         High Renaissance
# 27            Diego Velazquez                                  Baroque
# 28              Henri Matisse         Impressionism,Post-Impressionism
# 29               Jan van Eyck                     Northern Renaissance
# 30                Edgar Degas                            Impressionism
# 31                  Rembrandt                                  Baroque
# 32                     Titian               High Renaissance,Mannerism
# 33  Henri de Toulouse-Lautrec                       Post-Impressionism
# 34            Gustave Courbet                                  Realism
# 35           Camille Pissarro         Impressionism,Post-Impressionism
# 36             William Turner                              Romanticism
# 37               Edvard Munch                  Symbolism,Expressionism
# 38               Paul Cezanne                       Post-Impressionism
# 39           Eugene Delacroix                              Romanticism
# 40             Henri Rousseau                              Primitivism
# 41             Georges Seurat                       Post-Impressionism
# 42                  Paul Klee  Expressionism,Abstractionism,Surrealism
# 43              Piet Mondrian                            Neoplasticism
# 44                  Joan Miro                               Surrealism
# 45                Andy Warhol                                  Pop Art
# 46               Paul Gauguin             Symbolism,Post-Impressionism
# 47                    Raphael                         High Renaissance
# 48               Michelangelo                         High Renaissance
# 49            Jackson Pollock                   Abstract Expressionism
#
#     paintings
# 0         193
# 1          88
# 2          70
# 3          73
# 4         194
# 5         139
# 6          90
# 7          99
# 8         877
# 9         117
# 10        137
# 11        126
# 12        171
# 13        439
# 14        141
# 15        336
# 16        291
# 17        120
# 18         87
# 19        328
# 20        259
# 21        134
# 22        239
# 23        119
# 24        164
# 25         55
# 26        143
# 27        128
# 28        186
# 29         81
# 30        702
# 31        262
# 32        255
# 33         81
# 34         59
# 35         91
# 36         66
# 37         67
# 38         47
# 39         31
# 40         70
# 41         43
# 42        188
# 43         84
# 44        102
# 45        181
# 46        311
# 47        109
# 48         49
# 49         24

# %% [markdown]
# Here we can check out the top 5 genres and artists

# %%
top_genres = artists['genre'].value_counts()
top_genres[:5]
# Out:
# Baroque                 4
# Impressionism           4
# Northern Renaissance    4
# Post-Impressionism      4
# Romanticism             3
# Name: genre, dtype: int64

# %% [markdown]
# ****Note: These genres are only sorted from the number of artists belonging to that genre, not the number of paintings.****

# %% [markdown]
# We'll sort the list of artists by number of paintings instead to get a better overview of which artist has the most painings in the dataset.

# %%
no_of_paintings = artists[['name','paintings','genre']].sort_values(ascending=False, by='paintings')
no_of_paintings
# Out:
#                          name  paintings  \
# 8            Vincent van Gogh        877
# 30                Edgar Degas        702
# 13              Pablo Picasso        439
# 15      Pierre-Auguste Renoir        336
# 19             Albrecht Dürer        328
# 46               Paul Gauguin        311
# 16             Francisco Goya        291
# 31                  Rembrandt        262
# 20              Alfred Sisley        259
# 32                     Titian        255
# 22               Marc Chagall        239
# 4               Rene Magritte        194
# 0           Amedeo Modigliani        193
# 42                  Paul Klee        188
# 28              Henri Matisse        186
# 45                Andy Warhol        181
# 12             Mikhail Vrubel        171
# 24          Sandro Botticelli        164
# 26          Leonardo da Vinci        143
# 14          Peter Paul Rubens        141
# 5               Salvador Dali        139
# 10           Hieronymus Bosch        137
# 21             Pieter Bruegel        134
# 27            Diego Velazquez        128
# 11           Kazimir Malevich        126
# 17                Frida Kahlo        120
# 23          Giotto di Bondone        119
# 9                Gustav Klimt        117
# 47                    Raphael        109
# 44                  Joan Miro        102
# 7               Andrei Rublev         99
# 35           Camille Pissarro         91
# 6               Edouard Manet         90
# 1          Vasiliy Kandinskiy         88
# 18                   El Greco         87
# 43              Piet Mondrian         84
# 33  Henri de Toulouse-Lautrec         81
# 29               Jan van Eyck         81
# 3                Claude Monet         73
# 2                Diego Rivera         70
# 40             Henri Rousseau         70
# 37               Edvard Munch         67
# 36             William Turner         66
# 34            Gustave Courbet         59
# 25                 Caravaggio         55
# 48               Michelangelo         49
# 38               Paul Cezanne         47
# 41             Georges Seurat         43
# 39           Eugene Delacroix         31
# 49            Jackson Pollock         24
#
#                                       genre
# 8                        Post-Impressionism
# 30                            Impressionism
# 13                                   Cubism
# 15                            Impressionism
# 19                     Northern Renaissance
# 46             Symbolism,Post-Impressionism
# 16                              Romanticism
# 31                                  Baroque
# 20                            Impressionism
# 32               High Renaissance,Mannerism
# 22                              Primitivism
# 4                  Surrealism,Impressionism
# 0                             Expressionism
# 42  Expressionism,Abstractionism,Surrealism
# 28         Impressionism,Post-Impressionism
# 45                                  Pop Art
# 12                                Symbolism
# 24                        Early Renaissance
# 26                         High Renaissance
# 14                                  Baroque
# 5                                Surrealism
# 10                     Northern Renaissance
# 21                     Northern Renaissance
# 27                                  Baroque
# 11                              Suprematism
# 17                   Primitivism,Surrealism
# 23                        Proto Renaissance
# 9                     Symbolism,Art Nouveau
# 47                         High Renaissance
# 44                               Surrealism
# 7                             Byzantine Art
# 35         Impressionism,Post-Impressionism
# 6                     Realism,Impressionism
# 1              Expressionism,Abstractionism
# 18                                Mannerism
# 43                            Neoplasticism
# 33                       Post-Impressionism
# 29                     Northern Renaissance
# 3                             Impressionism
# 2                   Social Realism,Muralism
# 40                              Primitivism
# 37                  Symbolism,Expressionism
# 36                              Romanticism
# 34                                  Realism
# 25                                  Baroque
# 48                         High Renaissance
# 38                       Post-Impressionism
# 41                       Post-Impressionism
# 39                              Romanticism
# 49                   Abstract Expressionism

# %% [markdown]
# Van Gogh has been busy I see! Lets try printing some of the paintings to see what we're dealing with.

# %%
import matplotlib.pyplot as plt
import random

np.random.shuffle(dataset) #Shuffle the images

fig = plt.figure(figsize=(12,12))
for i in range(1,37):
    fig.add_subplot(6,6,i)
    plt.imshow(dataset[i])
    plt.axis('off')

# %% [markdown]
# **Beautiful!**
# There's some distortion from the rescaling and they look all weird normalized, this is due to plt.imshow only displaying ranges [0,1] and these are normalized to [-1,1] . If we were to not normalize them at the beginning they would look normal.

# %% [markdown]
# # Build the models

# %% [markdown]
# The generator will take in a random seed and generate an image from that seed, upsampling as much as needed. Note that increasing resolution will require retuning of the models as well as increase training time by a lot. I found that the generator needs to have quite a lot of capacity in order to keep up with the discriminator at later stages of training.
#
# architecture based on the findings and guidelines proposed in the paper:
#
# * Replace any pooling layers with strided convolutions (discriminator) and fractional-strided convolutions (generator).
# * Use batchnorm in both the generator and the discriminator.
# * Remove fully connected hidden layers for deeper architectures
# * Use ReLU activation in generator for all layers except for the output, which uses Tanh.
# * Use LeakyReLU activation in the discriminator for all layers.
#
# Further increasing conv layers will lead to mode collapse from what I've tried

# %%
def build_generator(seed_size, channels):
    
    model = Sequential()

    model.add(Dense(64*64,activation="relu",input_dim=seed_size)) #64x64 units
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
    
    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
    
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Optional additional upsampling goes here
    model.add(UpSampling2D(size = (2,2))) #4,4 for 128x128, 2,2 for 64x64
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    
    model.add(UpSampling2D(size=(2,2)))
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))
    
    return model

# %% [markdown]
# The discriminator is simply a CNN based image classifier which will output values of what it thinks is fake or real with 0 being fake and 1 being real

# %%
def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, 
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))
    
    return model

# %% [markdown]
# Here we use the untrained generator to generate an image (which will be very random)

# %%
SEED_SIZE = 100
IMAGE_CHANNELS = 3

generator = build_generator(SEED_SIZE,IMAGE_CHANNELS)

noise = tf.random.normal([1,SEED_SIZE])
generated_image = generator(noise,training=False)

plt.imshow(generated_image[0, :, :, 0])

# %% [markdown]
# Classify this random image with the untrained discriminator, the prediction will likely be 50%

# %%
image_shape = (HEIGHT, HEIGHT, IMAGE_CHANNELS)

discriminator = build_discriminator(image_shape)
decision = discriminator(generated_image)
print(decision)
# Out:
# tf.Tensor([[0.49986437]], shape=(1, 1), dtype=float32)

# %% [markdown]
# # Define loss functions for the models

# %% [markdown]
# **The discriminators loss** is based on its ability to distinguish real images from fakes. It compares its predictions on real images to an array of ones (remember 1 being real) and its predictions on fake images to an array of zeros (0 being fake). The goal is to classify all real images as 1 and all fakes as 0. The total loss is then these two losses added together.
#
# **The generators loss** is a measurement of how good it performed at fooling the discriminator. If the discriminator classifies the fake images as 1, the generator did a good job.

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %% [markdown]
# The two models optimizers are separated because we train them separately. I found a slightly lower generator LR to be beneficial.
#
# Beta value of 0.5 generated more stable models as per the findings in the paper "Unsupervised representation learning with deep convolutional generative adversarial networks"

# %%
generator_optimizer = tf.keras.optimizers.Adam(1.2e-4, 0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(1.5e-4, 0.5)

# %% [markdown]
# # Function for saving the generated images

# %%
GENERATED_ROWS = 7
GENERATED_COLS = 7
MARGIN = 2 # Give the images a little frame

def save_images(cnt, noise):
    #Define the "base" of the saved image as a big black canvas
    image_array = np.full(( 
      MARGIN + (GENERATED_ROWS * (WIDTH + MARGIN)), 
      MARGIN + (GENERATED_COLS * (HEIGHT + MARGIN)), 3), 
      0, dtype=np.uint8)
    
    generated_images =  generator.predict(noise)
    
    image_count = 0
    for row in range(GENERATED_ROWS):
        for col in range(GENERATED_COLS):
            r = row * (WIDTH + 2) + MARGIN
            c = col * (HEIGHT + 2) + MARGIN
            image_array[r:r+WIDTH , c:c+HEIGHT] = generated_images[image_count] * 127.5 + 127.5
            image_count += 1
            
    output_path  = os.path.join("/kaggle/working/generated2/")
    if not os.path.exists(output_path):
        os.makedirs(output_path)
        
    filename = os.path.join(output_path,f"train-{cnt}.png")
    im = Image.fromarray(image_array)
    im.save(filename)

# %% [markdown]
# # Train the models
#
# The training begins by providing a random seed to the generator, which is then used to generate an image. The discriminator then classifies images from both the fake and real dataset. The loss is calculated separately for each model and the gradients are updated.
#
# Based on the TensorFlow DCGAN tutorial

# %%
# This goes a bit deeper "behind the scenes" and manually sets the gradients
# instead of letting Keras and TensorFlow set it automatically. This is because
# the two models need to be trained separately
@tf.function
def train_step(images):
    seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])
    
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator(seed, training = True)
        
        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)
        
        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)
        
        
        gradients_of_generator = gen_tape.gradient(
            gen_loss,
            generator.trainable_variables
        )
        gradients_of_discriminator = disc_tape.gradient(
            disc_loss, 
            discriminator.trainable_variables
        )
        
        generator_optimizer.apply_gradients(zip(gradients_of_generator,
                                                generator.trainable_variables))
        
        discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, 
                                                    discriminator.trainable_variables))
        
        return gen_loss, disc_loss

# %%
def train(dataset, epochs):
    # Use a fixed seed for the saved images so we can watch their development
    fixed_seed = np.random.normal(0, 1, (GENERATED_ROWS * GENERATED_COLS, SEED_SIZE))
    
    for epoch in range(epochs):
        gen_loss_list = []
        disc_loss_list = []
        
        for image_batch in dataset:
            t = train_step(image_batch)
            gen_loss_list.append(t[0])
            disc_loss_list.append(t[1])
            
        g_loss = sum(gen_loss_list) / len(gen_loss_list) #calculate losses
        d_loss = sum(disc_loss_list) / len(disc_loss_list)
        
        print(f'Epoch {epoch+1}, gen loss = {g_loss}, disc loss = {d_loss}')
        
        save_images(epoch, fixed_seed)

# %% [markdown]
# Train the models, ideally we want to see the losses hovering at around the same values, indicating that they are both improving at similar rates

# %%
train(training_dataset, EPOCHS)
# Out:
# Epoch 1, gen loss = 1.874286413192749, disc loss = 1.4337680339813232
# Epoch 2, gen loss = 1.1391280889511108, disc loss = 1.4440906047821045
# Epoch 3, gen loss = 1.2134473323822021, disc loss = 1.4586342573165894
# Epoch 4, gen loss = 0.9712662696838379, disc loss = 1.5415853261947632
# Epoch 5, gen loss = 0.9789724946022034, disc loss = 1.4430208206176758
# Epoch 6, gen loss = 1.0643330812454224, disc loss = 1.412684440612793
# Epoch 7, gen loss = 0.8890519738197327, disc loss = 1.484031319618225
# Epoch 8, gen loss = 0.9031735062599182, disc loss = 1.4516619443893433
# Epoch 9, gen loss = 0.9738889336585999, disc loss = 1.4183062314987183
# Epoch 10, gen loss = 0.878196656703949, disc loss = 1.4941821098327637
# Epoch 11, gen loss = 0.8239067792892456, disc loss = 1.4459534883499146
# Epoch 12, gen loss = 1.0190680027008057, disc loss = 1.372251033782959
# Epoch 13, gen loss = 0.9030776023864746, disc loss = 1.4545592069625854
# Epoch 14, gen loss = 0.9922307133674622, disc loss = 1.371390700340271
# Epoch 15, gen loss = 0.9700077176094055, disc loss = 1.412345290184021
# Epoch 16, gen loss = 0.8950112462043762, disc loss = 1.4335614442825317
# Epoch 17, gen loss = 0.931770920753479, disc loss = 1.410070776939392
# Epoch 18, gen loss = 0.881795346736908, disc loss = 1.4395400285720825
# Epoch 19, gen loss = 0.8425710797309875, disc loss = 1.4436981678009033
# Epoch 20, gen loss = 0.8581108450889587, disc loss = 1.4253288507461548
# Epoch 21, gen loss = 0.8901150226593018, disc loss = 1.401280403137207
# Epoch 22, gen loss = 0.9496364593505859, disc loss = 1.3956048488616943
# Epoch 23, gen loss = 0.8649271130561829, disc loss = 1.4174342155456543
# Epoch 24, gen loss = 0.9737629890441895, disc loss = 1.3513593673706055
# Epoch 25, gen loss = 1.0243163108825684, disc loss = 1.336933970451355
# Epoch 26, gen loss = 0.9467718601226807, disc loss = 1.3758214712142944
# Epoch 27, gen loss = 0.9421650171279907, disc loss = 1.3566045761108398
# Epoch 28, gen loss = 0.961229681968689, disc loss = 1.3319154977798462
# Epoch 29, gen loss = 0.9494526982307434, disc loss = 1.3576669692993164
# Epoch 30, gen loss = 0.9487147331237793, disc loss = 1.3450313806533813
# Epoch 31, gen loss = 1.089557409286499, disc loss = 1.3164763450622559
# Epoch 32, gen loss = 1.0365018844604492, disc loss = 1.2896537780761719
# Epoch 33, gen loss = 1.0669753551483154, disc loss = 1.304187297821045
# Epoch 34, gen loss = 1.07201087474823, disc loss = 1.2947231531143188
# Epoch 35, gen loss = 1.2135155200958252, disc loss = 1.197880506515503
# Epoch 36, gen loss = 1.0320926904678345, disc loss = 1.3330332040786743
# Epoch 37, gen loss = 1.016649842262268, disc loss = 1.3268585205078125
# Epoch 38, gen loss = 1.0187747478485107, disc loss = 1.3184863328933716
# Epoch 39, gen loss = 1.0767871141433716, disc loss = 1.279883861541748
# Epoch 40, gen loss = 1.0103354454040527, disc loss = 1.3259629011154175
# Epoch 41, gen loss = 1.0121184587478638, disc loss = 1.324377417564392
# Epoch 42, gen loss = 0.9522811770439148, disc loss = 1.3612958192825317
# Epoch 43, gen loss = 0.9638961553573608, disc loss = 1.3492708206176758
# Epoch 44, gen loss = 1.0383211374282837, disc loss = 1.2717797756195068
# Epoch 45, gen loss = 0.9262912273406982, disc loss = 1.3886104822158813
# Epoch 46, gen loss = 0.9299894571304321, disc loss = 1.3622206449508667
# Epoch 47, gen loss = 0.9575925469398499, disc loss = 1.3328804969787598
# Epoch 48, gen loss = 0.9515368342399597, disc loss = 1.3487472534179688
# Epoch 49, gen loss = 0.9862660765647888, disc loss = 1.3152915239334106
# Epoch 50, gen loss = 0.998062252998352, disc loss = 1.3273528814315796
# Epoch 51, gen loss = 1.0723028182983398, disc loss = 1.2473115921020508
# Epoch 52, gen loss = 0.9721993803977966, disc loss = 1.337912917137146
# Epoch 53, gen loss = 0.9895720481872559, disc loss = 1.2995383739471436
# Epoch 54, gen loss = 1.0513207912445068, disc loss = 1.2761741876602173
# Epoch 55, gen loss = 1.0358816385269165, disc loss = 1.2917944192886353
# Epoch 56, gen loss = 1.0685230493545532, disc loss = 1.2559047937393188
# Epoch 57, gen loss = 1.149950623512268, disc loss = 1.2272974252700806
# Epoch 58, gen loss = 1.0195226669311523, disc loss = 1.3154841661453247
# Epoch 59, gen loss = 1.0447443723678589, disc loss = 1.275651216506958
# Epoch 60, gen loss = 1.1081173419952393, disc loss = 1.2342475652694702
# Epoch 61, gen loss = 1.151782751083374, disc loss = 1.2136480808258057
# Epoch 62, gen loss = 1.1020680665969849, disc loss = 1.243308424949646
# Epoch 63, gen loss = 1.1202166080474854, disc loss = 1.2429449558258057
# Epoch 64, gen loss = 1.1005561351776123, disc loss = 1.2501684427261353
# Epoch 65, gen loss = 1.1373006105422974, disc loss = 1.224185824394226
# Epoch 66, gen loss = 1.096246600151062, disc loss = 1.2527388334274292
# Epoch 67, gen loss = 1.1220980882644653, disc loss = 1.2182904481887817
# Epoch 68, gen loss = 1.1022473573684692, disc loss = 1.2456766366958618
# Epoch 69, gen loss = 1.100006103515625, disc loss = 1.2428501844406128
# Epoch 70, gen loss = 1.1162676811218262, disc loss = 1.2478415966033936
# Epoch 71, gen loss = 1.1426677703857422, disc loss = 1.2244417667388916
# Epoch 72, gen loss = 1.1464052200317383, disc loss = 1.225210189819336
# Epoch 73, gen loss = 1.1375468969345093, disc loss = 1.1871371269226074
# Epoch 74, gen loss = 1.2108100652694702, disc loss = 1.1660170555114746
# Epoch 75, gen loss = 1.2042269706726074, disc loss = 1.216843843460083
# Epoch 76, gen loss = 1.205627202987671, disc loss = 1.1760259866714478
# Epoch 77, gen loss = 1.2015163898468018, disc loss = 1.1784034967422485
# Epoch 78, gen loss = 1.1798174381256104, disc loss = 1.2185611724853516
# Epoch 79, gen loss = 1.1861704587936401, disc loss = 1.1822071075439453
# Epoch 80, gen loss = 1.2469251155853271, disc loss = 1.159398078918457
# Epoch 81, gen loss = 1.21858549118042, disc loss = 1.1636226177215576
# Epoch 82, gen loss = 1.2865805625915527, disc loss = 1.1422557830810547
# Epoch 83, gen loss = 1.3000754117965698, disc loss = 1.096636414527893
# Epoch 84, gen loss = 1.3162840604782104, disc loss = 1.1375406980514526
# Epoch 85, gen loss = 1.3111577033996582, disc loss = 1.1303776502609253
# Epoch 86, gen loss = 1.283597469329834, disc loss = 1.1962255239486694
# Epoch 87, gen loss = 1.2453467845916748, disc loss = 1.1533125638961792
# Epoch 88, gen loss = 1.2869974374771118, disc loss = 1.1358238458633423
# Epoch 89, gen loss = 1.3277002573013306, disc loss = 1.1325024366378784
# Epoch 90, gen loss = 1.2721171379089355, disc loss = 1.1352224349975586
# Epoch 91, gen loss = 1.2975678443908691, disc loss = 1.1308574676513672
# Epoch 92, gen loss = 1.3632680177688599, disc loss = 1.0981727838516235
# Epoch 93, gen loss = 1.326046347618103, disc loss = 1.1206943988800049
# Epoch 94, gen loss = 1.4063479900360107, disc loss = 1.0712761878967285
# Epoch 95, gen loss = 1.351943850517273, disc loss = 1.1289607286453247
# Epoch 96, gen loss = 1.3718657493591309, disc loss = 1.0983034372329712
# Epoch 97, gen loss = 1.3903706073760986, disc loss = 1.0967340469360352
# Epoch 98, gen loss = 1.4178285598754883, disc loss = 1.0499013662338257
# Epoch 99, gen loss = 1.3734369277954102, disc loss = 1.1209123134613037
# Epoch 100, gen loss = 1.3770650625228882, disc loss = 1.1180551052093506
# Epoch 101, gen loss = 1.419418454170227, disc loss = 1.0951511859893799
# Epoch 102, gen loss = 1.4342790842056274, disc loss = 1.0642735958099365
# Epoch 103, gen loss = 1.4112472534179688, disc loss = 1.1275075674057007
# Epoch 104, gen loss = 1.478792428970337, disc loss = 1.0320403575897217
# Epoch 105, gen loss = 1.4718776941299438, disc loss = 1.0609287023544312
# Epoch 106, gen loss = 1.4515401124954224, disc loss = 1.0734710693359375
# Epoch 107, gen loss = 1.4778187274932861, disc loss = 1.031689167022705
# Epoch 108, gen loss = 1.5354132652282715, disc loss = 1.0450749397277832
# Epoch 109, gen loss = 1.4603378772735596, disc loss = 1.0972243547439575
# Epoch 110, gen loss = 1.5214136838912964, disc loss = 1.0376149415969849
# Epoch 111, gen loss = 1.4202862977981567, disc loss = 1.079824686050415
# Epoch 112, gen loss = 1.4710065126419067, disc loss = 1.0556426048278809
# Epoch 113, gen loss = 1.5646404027938843, disc loss = 1.0126582384109497
# Epoch 114, gen loss = 1.5342665910720825, disc loss = 1.035722017288208
# Epoch 115, gen loss = 1.5176334381103516, disc loss = 1.0299937725067139
# Epoch 116, gen loss = 1.5431913137435913, disc loss = 1.0238184928894043
# Epoch 117, gen loss = 1.5746451616287231, disc loss = 1.0365424156188965
# Epoch 118, gen loss = 1.5851595401763916, disc loss = 0.980898916721344
# Epoch 119, gen loss = 1.6707637310028076, disc loss = 0.9494547247886658
# Epoch 120, gen loss = 1.68240225315094, disc loss = 0.9646992683410645
# Epoch 121, gen loss = 1.6069976091384888, disc loss = 1.016352653503418
# Epoch 122, gen loss = 1.5392650365829468, disc loss = 1.0638717412948608
# Epoch 123, gen loss = 1.6079857349395752, disc loss = 1.0373669862747192
# Epoch 124, gen loss = 1.6422523260116577, disc loss = 0.9728982448577881
# Epoch 125, gen loss = 1.637363314628601, disc loss = 0.9796386957168579
# Epoch 126, gen loss = 1.536719560623169, disc loss = 1.0299168825149536
# Epoch 127, gen loss = 1.5644917488098145, disc loss = 1.0335299968719482
# Epoch 128, gen loss = 1.5762929916381836, disc loss = 1.0271639823913574
# Epoch 129, gen loss = 1.6119050979614258, disc loss = 0.9873640537261963
# Epoch 130, gen loss = 1.67338228225708, disc loss = 0.9566658139228821
# Epoch 131, gen loss = 1.660787582397461, disc loss = 0.9700601100921631
# Epoch 132, gen loss = 1.758205771446228, disc loss = 0.9466984868049622
# Epoch 133, gen loss = 1.6913686990737915, disc loss = 0.9802589416503906
# Epoch 134, gen loss = 1.6459667682647705, disc loss = 1.0141522884368896
# Epoch 135, gen loss = 1.6300431489944458, disc loss = 0.9617299437522888
# Epoch 136, gen loss = 1.7140157222747803, disc loss = 0.942812442779541
# Epoch 137, gen loss = 1.6746594905853271, disc loss = 1.006328821182251
# Epoch 138, gen loss = 1.6810238361358643, disc loss = 0.9397412538528442
# Epoch 139, gen loss = 1.7482699155807495, disc loss = 0.9239348769187927
# Epoch 140, gen loss = 1.7001216411590576, disc loss = 0.9754480719566345
# Epoch 141, gen loss = 1.7409002780914307, disc loss = 0.9511924982070923
# Epoch 142, gen loss = 1.692660927772522, disc loss = 0.9849212765693665
# Epoch 143, gen loss = 1.750748872756958, disc loss = 0.9647641777992249
# Epoch 144, gen loss = 1.7706092596054077, disc loss = 0.9190895557403564
# Epoch 145, gen loss = 1.6861766576766968, disc loss = 1.0055819749832153
# Epoch 146, gen loss = 1.7222082614898682, disc loss = 0.9794212579727173
# Epoch 147, gen loss = 1.603654384613037, disc loss = 1.0250978469848633
# Epoch 148, gen loss = 1.7005977630615234, disc loss = 0.9673190116882324
# Epoch 149, gen loss = 1.6953363418579102, disc loss = 0.9657148718833923
# Epoch 150, gen loss = 1.7384124994277954, disc loss = 0.9366625547409058
# Epoch 151, gen loss = 1.750426173210144, disc loss = 0.937425971031189
# Epoch 152, gen loss = 1.757414698600769, disc loss = 0.949834942817688
# Epoch 153, gen loss = 1.7869077920913696, disc loss = 0.9160799980163574
# Epoch 154, gen loss = 1.7689684629440308, disc loss = 0.9084559082984924
# Epoch 155, gen loss = 1.7439521551132202, disc loss = 0.969562292098999
# Epoch 156, gen loss = 1.7652181386947632, disc loss = 0.9449552893638611
# Epoch 157, gen loss = 1.7910248041152954, disc loss = 0.9397950768470764
# Epoch 158, gen loss = 1.7530348300933838, disc loss = 0.9488940238952637
# Epoch 159, gen loss = 1.7889963388442993, disc loss = 0.9437298774719238
# Epoch 160, gen loss = 1.8149219751358032, disc loss = 0.880679190158844
# Epoch 161, gen loss = 1.8913795948028564, disc loss = 0.8850032091140747
# Epoch 162, gen loss = 1.8429064750671387, disc loss = 0.8845208883285522
# Epoch 163, gen loss = 1.9020929336547852, disc loss = 0.864271879196167
# Epoch 164, gen loss = 1.8409154415130615, disc loss = 0.9117501378059387
# Epoch 165, gen loss = 1.871354579925537, disc loss = 0.9241160750389099
# Epoch 166, gen loss = 1.827438235282898, disc loss = 0.9233174324035645
# Epoch 167, gen loss = 1.8858317136764526, disc loss = 0.887756884098053
# Epoch 168, gen loss = 1.866948127746582, disc loss = 0.9246885180473328
# Epoch 169, gen loss = 1.900103211402893, disc loss = 0.8773977756500244
# Epoch 170, gen loss = 1.87330162525177, disc loss = 0.9128546118736267
# Epoch 171, gen loss = 1.8945722579956055, disc loss = 0.8632742762565613
# Epoch 172, gen loss = 1.8970898389816284, disc loss = 0.9089556336402893
# Epoch 173, gen loss = 1.844136118888855, disc loss = 0.9354438185691833
# Epoch 174, gen loss = 1.890533208847046, disc loss = 0.8864023685455322
# Epoch 175, gen loss = 1.9259648323059082, disc loss = 0.8782281875610352
# Epoch 176, gen loss = 1.9867634773254395, disc loss = 0.8324140310287476
# Epoch 177, gen loss = 1.9508206844329834, disc loss = 0.8991194367408752
# Epoch 178, gen loss = 1.995848298072815, disc loss = 0.8287356495857239
# Epoch 179, gen loss = 2.0427772998809814, disc loss = 0.8324432373046875
# Epoch 180, gen loss = 1.975664734840393, disc loss = 0.8680272102355957
# Epoch 181, gen loss = 1.9657195806503296, disc loss = 0.8780537247657776
# Epoch 182, gen loss = 1.9953776597976685, disc loss = 0.8757691979408264
# Epoch 183, gen loss = 1.9841281175613403, disc loss = 0.8617262840270996
# Epoch 184, gen loss = 2.0004117488861084, disc loss = 0.8364657163619995
# Epoch 185, gen loss = 2.0290274620056152, disc loss = 0.8352909684181213
# Epoch 186, gen loss = 2.0498526096343994, disc loss = 0.824699878692627
# Epoch 187, gen loss = 2.021141290664673, disc loss = 0.8258607387542725
# Epoch 188, gen loss = 2.0219810009002686, disc loss = 0.8395715355873108
# Epoch 189, gen loss = 2.079571008682251, disc loss = 0.8336031436920166
# Epoch 190, gen loss = 2.0447325706481934, disc loss = 0.8212542533874512
# Epoch 191, gen loss = 2.1946237087249756, disc loss = 0.7764908671379089
# Epoch 192, gen loss = 2.057298183441162, disc loss = 0.8424867391586304
# Epoch 193, gen loss = 2.058570146560669, disc loss = 0.8273999094963074
# Epoch 194, gen loss = 2.0877459049224854, disc loss = 0.8301665186882019
# Epoch 195, gen loss = 2.119907855987549, disc loss = 0.7964507937431335
# Epoch 196, gen loss = 2.1519999504089355, disc loss = 0.7775301337242126
# Epoch 197, gen loss = 2.184727430343628, disc loss = 0.7804379463195801
# Epoch 198, gen loss = 2.2047131061553955, disc loss = 0.7955023050308228
# Epoch 199, gen loss = 2.082821846008301, disc loss = 0.8533921241760254
# Epoch 200, gen loss = 2.1744775772094727, disc loss = 0.7942437529563904
# Epoch 201, gen loss = 2.19110369682312, disc loss = 0.7482454180717468
# Epoch 202, gen loss = 2.2080249786376953, disc loss = 0.7691367268562317
# Epoch 203, gen loss = 2.181584119796753, disc loss = 0.8151810169219971
# Epoch 204, gen loss = 2.239736318588257, disc loss = 0.7796463966369629
# Epoch 205, gen loss = 2.146827459335327, disc loss = 0.8179875612258911
# Epoch 206, gen loss = 2.2803702354431152, disc loss = 0.768792986869812
# Epoch 207, gen loss = 2.2493646144866943, disc loss = 0.7689406275749207
# Epoch 208, gen loss = 2.210355281829834, disc loss = 0.7605563402175903
# Epoch 209, gen loss = 2.2570431232452393, disc loss = 0.7665084600448608
# Epoch 210, gen loss = 2.271188735961914, disc loss = 0.7956520915031433
# Epoch 211, gen loss = 2.2508907318115234, disc loss = 0.7696988582611084
# Epoch 212, gen loss = 2.291290044784546, disc loss = 0.744368314743042
# Epoch 213, gen loss = 2.302507162094116, disc loss = 0.752460777759552
# Epoch 214, gen loss = 2.2753334045410156, disc loss = 0.7480467557907104
# Epoch 215, gen loss = 2.2961654663085938, disc loss = 0.7342085838317871
# Epoch 216, gen loss = 2.3501508235931396, disc loss = 0.7167447805404663
# Epoch 217, gen loss = 2.281236410140991, disc loss = 0.7760258316993713
# Epoch 218, gen loss = 2.330254077911377, disc loss = 0.7450156807899475
# Epoch 219, gen loss = 2.4520177841186523, disc loss = 0.7224254012107849
# Epoch 220, gen loss = 2.3472421169281006, disc loss = 0.7637382745742798
# Epoch 221, gen loss = 2.3538312911987305, disc loss = 0.7391854524612427
# Epoch 222, gen loss = 2.335061550140381, disc loss = 0.7306215167045593
# Epoch 223, gen loss = 2.405221939086914, disc loss = 0.7658199071884155
# Epoch 224, gen loss = 2.262082815170288, disc loss = 0.7864328026771545
# Epoch 225, gen loss = 2.4199023246765137, disc loss = 0.7096093893051147
# Epoch 226, gen loss = 2.4368064403533936, disc loss = 0.7026536464691162
# Epoch 227, gen loss = 2.357771396636963, disc loss = 0.7689653038978577
# Epoch 228, gen loss = 2.355989456176758, disc loss = 0.7545738816261292
# Epoch 229, gen loss = 2.441680431365967, disc loss = 0.7323153018951416
# Epoch 230, gen loss = 2.424373149871826, disc loss = 0.7178493142127991
# Epoch 231, gen loss = 2.330996513366699, disc loss = 0.7501282095909119
# Epoch 232, gen loss = 2.463336229324341, disc loss = 0.7194263935089111
# Epoch 233, gen loss = 2.375152587890625, disc loss = 0.7388320565223694
# Epoch 234, gen loss = 2.457563877105713, disc loss = 0.7319898009300232
# Epoch 235, gen loss = 2.4743735790252686, disc loss = 0.7336968183517456
# Epoch 236, gen loss = 2.4451797008514404, disc loss = 0.7108903527259827
# Epoch 237, gen loss = 2.515178680419922, disc loss = 0.6976546049118042
# Epoch 238, gen loss = 2.4632515907287598, disc loss = 0.7297932505607605
# Epoch 239, gen loss = 2.3807873725891113, disc loss = 0.784597635269165
# Epoch 240, gen loss = 2.458733558654785, disc loss = 0.716404139995575
# Epoch 241, gen loss = 2.4637439250946045, disc loss = 0.6884822249412537
# Epoch 242, gen loss = 2.5371062755584717, disc loss = 0.6781955361366272
# Epoch 243, gen loss = 2.6202757358551025, disc loss = 0.7106427550315857
# Epoch 244, gen loss = 2.5257129669189453, disc loss = 0.6919921636581421
# Epoch 245, gen loss = 2.5416886806488037, disc loss = 0.6905829906463623
# Epoch 246, gen loss = 2.571877956390381, disc loss = 0.64192134141922
# Epoch 247, gen loss = 2.5220437049865723, disc loss = 0.7459167838096619
# Epoch 248, gen loss = 2.512200355529785, disc loss = 0.6713981032371521
# Epoch 249, gen loss = 2.5562288761138916, disc loss = 0.7244013547897339
# Epoch 250, gen loss = 2.4921114444732666, disc loss = 0.7386019229888916

# %% [markdown]
# # Zip images for download

# %%
# !zip -r images.zip "/kaggle/working/generated2/"
# Out:
#   adding: kaggle/working/generated2/ (stored 0%)
#   adding: kaggle/working/generated2/train-204.png (deflated 0%)
#   adding: kaggle/working/generated2/train-67.png (deflated 0%)
#   adding: kaggle/working/generated2/train-185.png (deflated 0%)
#   adding: kaggle/working/generated2/train-248.png (deflated 0%)
#   adding: kaggle/working/generated2/train-95.png (deflated 0%)
#   adding: kaggle/working/generated2/train-92.png (deflated 0%)
#   adding: kaggle/working/generated2/train-168.png (deflated 0%)
#   adding: kaggle/working/generated2/train-155.png (deflated 0%)
#   adding: kaggle/working/generated2/train-54.png (deflated 0%)
#   adding: kaggle/working/generated2/train-73.png (deflated 0%)
#   adding: kaggle/working/generated2/train-240.png (deflated 0%)
#   adding: kaggle/working/generated2/train-200.png (deflated 0%)
#   adding: kaggle/working/generated2/train-99.png (deflated 0%)
#   adding: kaggle/working/generated2/train-180.png (deflated 0%)
#   adding: kaggle/working/generated2/train-78.png (deflated 0%)
#   adding: kaggle/working/generated2/train-196.png (deflated 0%)
#   adding: kaggle/working/generated2/train-63.png (deflated 0%)
#   adding: kaggle/working/generated2/train-153.png (deflated 0%)
#   adding: kaggle/working/generated2/train-220.png (deflated 0%)
#   adding: kaggle/working/generated2/train-195.png (deflated 0%)
#   adding: kaggle/working/generated2/train-76.png (deflated 0%)
#   adding: kaggle/working/generated2/train-218.png (deflated 0%)
#   adding: kaggle/working/generated2/train-215.png (deflated 0%)
#   adding: kaggle/working/generated2/train-226.png (deflated 0%)
#   adding: kaggle/working/generated2/train-125.png (deflated 0%)
#   adding: kaggle/working/generated2/train-100.png (deflated 0%)
#   adding: kaggle/working/generated2/train-60.png (deflated 0%)
#   adding: kaggle/working/generated2/train-18.png (deflated 0%)
#   adding: kaggle/working/generated2/train-156.png (deflated 0%)
#   adding: kaggle/working/generated2/train-216.png (deflated 0%)
#   adding: kaggle/working/generated2/train-103.png (deflated 0%)
#   adding: kaggle/working/generated2/train-38.png (deflated 0%)
#   adding: kaggle/working/generated2/train-17.png (deflated 0%)
#   adding: kaggle/working/generated2/train-219.png (deflated 0%)
#   adding: kaggle/working/generated2/train-214.png (deflated 0%)
#   adding: kaggle/working/generated2/train-140.png (deflated 0%)
#   adding: kaggle/working/generated2/train-175.png (deflated 0%)
#   adding: kaggle/working/generated2/train-222.png (deflated 0%)
#   adding: kaggle/working/generated2/train-11.png (deflated 0%)
#   adding: kaggle/working/generated2/train-12.png (deflated 0%)
#   adding: kaggle/working/generated2/train-127.png (deflated 0%)
#   adding: kaggle/working/generated2/train-198.png (deflated 0%)
#   adding: kaggle/working/generated2/train-44.png (deflated 0%)
#   adding: kaggle/working/generated2/train-22.png (deflated 0%)
#   adding: kaggle/working/generated2/train-135.png (deflated 0%)
#   adding: kaggle/working/generated2/train-199.png (deflated 0%)
#   adding: kaggle/working/generated2/train-107.png (deflated 0%)
#   adding: kaggle/working/generated2/train-116.png (deflated 0%)
#   adding: kaggle/working/generated2/train-56.png (deflated 0%)
#   adding: kaggle/working/generated2/train-65.png (deflated 0%)
#   adding: kaggle/working/generated2/train-70.png (deflated 0%)
#   adding: kaggle/working/generated2/train-123.png (deflated 0%)
#   adding: kaggle/working/generated2/train-212.png (deflated 0%)
#   adding: kaggle/working/generated2/train-68.png (deflated 0%)
#   adding: kaggle/working/generated2/train-42.png (deflated 0%)
#   adding: kaggle/working/generated2/train-160.png (deflated 0%)
#   adding: kaggle/working/generated2/train-64.png (deflated 0%)
#   adding: kaggle/working/generated2/train-101.png (deflated 0%)
#   adding: kaggle/working/generated2/train-113.png (deflated 0%)
#   adding: kaggle/working/generated2/train-197.png (deflated 0%)
#   adding: kaggle/working/generated2/train-40.png (deflated 0%)
#   adding: kaggle/working/generated2/train-232.png (deflated 0%)
#   adding: kaggle/working/generated2/train-193.png (deflated 0%)
#   adding: kaggle/working/generated2/train-124.png (deflated 0%)
#   adding: kaggle/working/generated2/train-169.png (deflated 0%)
#   adding: kaggle/working/generated2/train-154.png (deflated 0%)
#   adding: kaggle/working/generated2/train-230.png (deflated 0%)
#   adding: kaggle/working/generated2/train-152.png (deflated 0%)
#   adding: kaggle/working/generated2/train-79.png (deflated 0%)
#   adding: kaggle/working/generated2/train-171.png (deflated 0%)
#   adding: kaggle/working/generated2/train-163.png (deflated 0%)
#   adding: kaggle/working/generated2/train-159.png (deflated 0%)
#   adding: kaggle/working/generated2/train-3.png (deflated 0%)
#   adding: kaggle/working/generated2/train-131.png (deflated 0%)
#   adding: kaggle/working/generated2/train-110.png (deflated 0%)
#   adding: kaggle/working/generated2/train-177.png (deflated 0%)
#   adding: kaggle/working/generated2/train-72.png (deflated 0%)
#   adding: kaggle/working/generated2/train-149.png (deflated 0%)
#   adding: kaggle/working/generated2/train-213.png (deflated 0%)
#   adding: kaggle/working/generated2/train-166.png (deflated 0%)
#   adding: kaggle/working/generated2/train-157.png (deflated 0%)
#   adding: kaggle/working/generated2/train-36.png (deflated 0%)
#   adding: kaggle/working/generated2/train-77.png (deflated 0%)
#   adding: kaggle/working/generated2/train-75.png (deflated 0%)
#   adding: kaggle/working/generated2/train-191.png (deflated 0%)
#   adding: kaggle/working/generated2/train-161.png (deflated 0%)
#   adding: kaggle/working/generated2/train-136.png (deflated 0%)
#   adding: kaggle/working/generated2/train-23.png (deflated 0%)
#   adding: kaggle/working/generated2/train-16.png (deflated 0%)
#   adding: kaggle/working/generated2/train-30.png (deflated 0%)
#   adding: kaggle/working/generated2/train-34.png (deflated 0%)
#   adding: kaggle/working/generated2/train-25.png (deflated 0%)
#   adding: kaggle/working/generated2/train-51.png (deflated 0%)
#   adding: kaggle/working/generated2/train-1.png (deflated 0%)
#   adding: kaggle/working/generated2/train-194.png (deflated 0%)
#   adding: kaggle/working/generated2/train-47.png (deflated 0%)
#   adding: kaggle/working/generated2/train-178.png (deflated 0%)
#   adding: kaggle/working/generated2/train-80.png (deflated 0%)
#   adding: kaggle/working/generated2/train-10.png (deflated 0%)
#   adding: kaggle/working/generated2/train-8.png (deflated 0%)
#   adding: kaggle/working/generated2/train-211.png (deflated 0%)
#   adding: kaggle/working/generated2/train-142.png (deflated 0%)
#   adding: kaggle/working/generated2/train-183.png (deflated 0%)
#   adding: kaggle/working/generated2/train-167.png (deflated 0%)
#   adding: kaggle/working/generated2/train-130.png (deflated 0%)
#   adding: kaggle/working/generated2/train-46.png (deflated 0%)
#   adding: kaggle/working/generated2/train-143.png (deflated 0%)
#   adding: kaggle/working/generated2/train-237.png (deflated 0%)
#   adding: kaggle/working/generated2/train-209.png (deflated 0%)
#   adding: kaggle/working/generated2/train-217.png (deflated 0%)
#   adding: kaggle/working/generated2/train-234.png (deflated 0%)
#   adding: kaggle/working/generated2/train-112.png (deflated 0%)
#   adding: kaggle/working/generated2/train-48.png (deflated 0%)
#   adding: kaggle/working/generated2/train-134.png (deflated 0%)
#   adding: kaggle/working/generated2/train-182.png (deflated 0%)
#   adding: kaggle/working/generated2/train-132.png (deflated 0%)
#   adding: kaggle/working/generated2/train-243.png (deflated 0%)
#   adding: kaggle/working/generated2/train-221.png (deflated 0%)
#   adding: kaggle/working/generated2/train-170.png (deflated 0%)
#   adding: kaggle/working/generated2/train-84.png (deflated 0%)
#   adding: kaggle/working/generated2/train-190.png (deflated 0%)
#   adding: kaggle/working/generated2/train-45.png (deflated 0%)
#   adding: kaggle/working/generated2/train-26.png (deflated 0%)
#   adding: kaggle/working/generated2/train-117.png (deflated 0%)
#   adding: kaggle/working/generated2/train-187.png (deflated 0%)
#   adding: kaggle/working/generated2/train-108.png (deflated 0%)
#   adding: kaggle/working/generated2/train-206.png (deflated 0%)
#   adding: kaggle/working/generated2/train-31.png (deflated 0%)
#   adding: kaggle/working/generated2/train-43.png (deflated 0%)
#   adding: kaggle/working/generated2/train-145.png (deflated 0%)
#   adding: kaggle/working/generated2/train-20.png (deflated 0%)
#   adding: kaggle/working/generated2/train-223.png (deflated 0%)
#   adding: kaggle/working/generated2/train-245.png (deflated 0%)
#   adding: kaggle/working/generated2/train-122.png (deflated 0%)
#   adding: kaggle/working/generated2/train-244.png (deflated 0%)
#   adding: kaggle/working/generated2/train-179.png (deflated 0%)
#   adding: kaggle/working/generated2/train-119.png (deflated 0%)
#   adding: kaggle/working/generated2/train-5.png (deflated 0%)
#   adding: kaggle/working/generated2/train-55.png (deflated 0%)
#   adding: kaggle/working/generated2/train-96.png (deflated 0%)
#   adding: kaggle/working/generated2/train-236.png (deflated 0%)
#   adding: kaggle/working/generated2/train-147.png (deflated 0%)
#   adding: kaggle/working/generated2/train-104.png (deflated 0%)
#   adding: kaggle/working/generated2/train-231.png (deflated 0%)
#   adding: kaggle/working/generated2/train-57.png (deflated 0%)
#   adding: kaggle/working/generated2/train-6.png (deflated 0%)
#   adding: kaggle/working/generated2/train-62.png (deflated 0%)
#   adding: kaggle/working/generated2/train-138.png (deflated 0%)
#   adding: kaggle/working/generated2/train-61.png (deflated 0%)
#   adding: kaggle/working/generated2/train-93.png (deflated 0%)
#   adding: kaggle/working/generated2/train-0.png (deflated 0%)
#   adding: kaggle/working/generated2/train-14.png (deflated 0%)
#   adding: kaggle/working/generated2/train-69.png (deflated 0%)
#   adding: kaggle/working/generated2/train-139.png (deflated 0%)
#   adding: kaggle/working/generated2/train-111.png (deflated 0%)
#   adding: kaggle/working/generated2/train-229.png (deflated 0%)
#   adding: kaggle/working/generated2/train-202.png (deflated 0%)
#   adding: kaggle/working/generated2/train-208.png (deflated 0%)
#   adding: kaggle/working/generated2/train-90.png (deflated 0%)
#   adding: kaggle/working/generated2/train-227.png (deflated 0%)
#   adding: kaggle/working/generated2/train-235.png (deflated 0%)
#   adding: kaggle/working/generated2/train-37.png (deflated 0%)
#   adding: kaggle/working/generated2/train-207.png (deflated 0%)
#   adding: kaggle/working/generated2/train-29.png (deflated 0%)
#   adding: kaggle/working/generated2/train-246.png (deflated 0%)
#   adding: kaggle/working/generated2/train-174.png (deflated 0%)
#   adding: kaggle/working/generated2/train-13.png (deflated 0%)
#   adding: kaggle/working/generated2/train-164.png (deflated 0%)
#   adding: kaggle/working/generated2/train-241.png (deflated 0%)
#   adding: kaggle/working/generated2/train-83.png (deflated 0%)
#   adding: kaggle/working/generated2/train-238.png (deflated 0%)
#   adding: kaggle/working/generated2/train-118.png (deflated 0%)
#   adding: kaggle/working/generated2/train-33.png (deflated 0%)
#   adding: kaggle/working/generated2/train-128.png (deflated 0%)
#   adding: kaggle/working/generated2/train-173.png (deflated 0%)
#   adding: kaggle/working/generated2/train-210.png (deflated 0%)
#   adding: kaggle/working/generated2/train-162.png (deflated 0%)
#   adding: kaggle/working/generated2/train-89.png (deflated 0%)
#   adding: kaggle/working/generated2/train-146.png (deflated 0%)
#   adding: kaggle/working/generated2/train-81.png (deflated 0%)
#   adding: kaggle/working/generated2/train-181.png (deflated 0%)
#   adding: kaggle/working/generated2/train-102.png (deflated 0%)
#   adding: kaggle/working/generated2/train-58.png (deflated 0%)
#   adding: kaggle/working/generated2/train-205.png (deflated 0%)
#   adding: kaggle/working/generated2/train-141.png (deflated 0%)
#   adding: kaggle/working/generated2/train-88.png (deflated 0%)
#   adding: kaggle/working/generated2/train-52.png (deflated 0%)
#   adding: kaggle/working/generated2/train-97.png (deflated 0%)
#   adding: kaggle/working/generated2/train-225.png (deflated 0%)
#   adding: kaggle/working/generated2/train-184.png (deflated 0%)
#   adding: kaggle/working/generated2/train-192.png (deflated 0%)
#   adding: kaggle/working/generated2/train-50.png (deflated 0%)
#   adding: kaggle/working/generated2/train-74.png (deflated 0%)
#   adding: kaggle/working/generated2/train-85.png (deflated 0%)
#   adding: kaggle/working/generated2/train-82.png (deflated 0%)
#   adding: kaggle/working/generated2/train-233.png (deflated 0%)
#   adding: kaggle/working/generated2/train-249.png (deflated 0%)
#   adding: kaggle/working/generated2/train-247.png (deflated 0%)
#   adding: kaggle/working/generated2/train-189.png (deflated 0%)
#   adding: kaggle/working/generated2/train-41.png (deflated 0%)
#   adding: kaggle/working/generated2/train-87.png (deflated 0%)
#   adding: kaggle/working/generated2/train-2.png (deflated 0%)
#   adding: kaggle/working/generated2/train-105.png (deflated 0%)
#   adding: kaggle/working/generated2/train-106.png (deflated 0%)
#   adding: kaggle/working/generated2/train-114.png (deflated 0%)
#   adding: kaggle/working/generated2/train-186.png (deflated 0%)
#   adding: kaggle/working/generated2/train-91.png (deflated 0%)
#   adding: kaggle/working/generated2/train-158.png (deflated 0%)
#   adding: kaggle/working/generated2/train-120.png (deflated 0%)
#   adding: kaggle/working/generated2/train-115.png (deflated 0%)
#   adding: kaggle/working/generated2/train-39.png (deflated 0%)
#   adding: kaggle/working/generated2/train-4.png (deflated 0%)
#   adding: kaggle/working/generated2/train-53.png (deflated 0%)
#   adding: kaggle/working/generated2/train-7.png (deflated 0%)
#   adding: kaggle/working/generated2/train-121.png (deflated 0%)
#   adding: kaggle/working/generated2/train-24.png (deflated 0%)
#   adding: kaggle/working/generated2/train-109.png (deflated 0%)
#   adding: kaggle/working/generated2/train-126.png (deflated 0%)
#   adding: kaggle/working/generated2/train-98.png (deflated 0%)
#   adding: kaggle/working/generated2/train-15.png (deflated 0%)
#   adding: kaggle/working/generated2/train-203.png (deflated 0%)
#   adding: kaggle/working/generated2/train-228.png (deflated 0%)
#   adding: kaggle/working/generated2/train-144.png (deflated 0%)
#   adding: kaggle/working/generated2/train-129.png (deflated 0%)
#   adding: kaggle/working/generated2/train-59.png (deflated 0%)
#   adding: kaggle/working/generated2/train-9.png (deflated 0%)
#   adding: kaggle/working/generated2/train-188.png (deflated 0%)
#   adding: kaggle/working/generated2/train-19.png (deflated 0%)
#   adding: kaggle/working/generated2/train-148.png (deflated 0%)
#   adding: kaggle/working/generated2/train-137.png (deflated 0%)
#   adding: kaggle/working/generated2/train-150.png (deflated 0%)
#   adding: kaggle/working/generated2/train-27.png (deflated 0%)
#   adding: kaggle/working/generated2/train-133.png (deflated 0%)
#   adding: kaggle/working/generated2/train-201.png (deflated 0%)
#   adding: kaggle/working/generated2/train-151.png (deflated 0%)
#   adding: kaggle/working/generated2/train-21.png (deflated 0%)
#   adding: kaggle/working/generated2/train-172.png (deflated 0%)
#   adding: kaggle/working/generated2/train-94.png (deflated 0%)
#   adding: kaggle/working/generated2/train-28.png (deflated 0%)
#   adding: kaggle/working/generated2/train-32.png (deflated 0%)
#   adding: kaggle/working/generated2/train-86.png (deflated 0%)
#   adding: kaggle/working/generated2/train-239.png (deflated 0%)
#   adding: kaggle/working/generated2/train-35.png (deflated 0%)
#   adding: kaggle/working/generated2/train-66.png (deflated 0%)
#   adding: kaggle/working/generated2/train-71.png (deflated 0%)
#   adding: kaggle/working/generated2/train-176.png (deflated 0%)
#   adding: kaggle/working/generated2/train-49.png (deflated 0%)
#   adding: kaggle/working/generated2/train-224.png (deflated 0%)
#   adding: kaggle/working/generated2/train-242.png (deflated 0%)
#   adding: kaggle/working/generated2/train-165.png (deflated 0%)

# %%
from IPython.display import FileLink
FileLink(r'images.zip')
# Out:
# /kaggle/working/images.zip

# %% [markdown]
# # Bonus: printing a random set of pictures generated by the trained generator
#
# Just for playing with it to see what we find, generates a new seed everytime

# %%
seed2 = tf.random.normal([BATCH_SIZE, SEED_SIZE])
generated_images2 = generator(seed2, training = True)

generated_images2 =0.5 * generated_images2 + 0.5

fig = plt.figure(figsize=(10,10))
for i in range(1,21):
    fig.add_subplot(5,5,i)
    plt.imshow(generated_images2[i])
    plt.axis('off')
